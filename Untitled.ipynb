# %%
# Out:
# hello world

# %%
class StudentManagementSystem:
    def __init__(self):
        self.students = {}  
    
    def add_student(self, student_id, name, student_class, grades=None):
        """"
        Add a new student to the system.
        
         student_id:in
     name: Name of the student
         student_class
        n grades: 
        """
        if student_id in self.students:
            print(f"Student ID {student_id} already exists.")
            return
        
        if grades is None:
            grades = []
        
        self.students[student_id] = {
            'name': name,
            'class': student_class,
            'grades': grades
        }
        print(f"Student {name} added .")

    def update_grades(self, student_id, new_grades):
        """
        Update .
        
         student_id
        """
        if student_id not in self.students:
            print(f"Student ID {student_id} not found.")
            return
        
        self.students[student_id]['grades'] = new_grades
        print(f"Grades updated for student ID {student_id}.")

    def calculate_average(self, student_id):
        """
       t.
        
     student_id
        """
        if student_id not in self.students:
            print(f"Student ID {student_id} not found.")
            return None
        
        grades = self.students[student_id]['grades']
        if not grades:
            return 0
        
        average = sum(grades) / len(grades)
        return average

    
       
       

    def print_report(self):
       
       
        for student_class, details in report.items():
            print(f"Class: {student_class}")
            print(f"  Student ID: {details['student_id']}")
            print(f"  Name: {details['name']}")
            print(f"  Average Grade: {details['average_grade']:.2f}")
            print()

if __name__ == "__main__":
    system = StudentManagementSystem()
    
   
   system.add_student("S001", "Alice", "Math", [85, 90, 92])
    system.add_student("S002", "Bob", "Science", [88, 76, 91])
    system.add_student("S003", "Charlie", "Math", [78, 82, 80])
    
   
    system.update_grades("S001", [90, 92, 95])
    
    print(f"Alice's average grade: {system.calculate_average('S001'):.2f}")
    print(f"Bob's average grade: {system.calculate_average('S002'):.2f}")
    

    system.print_report()
    
    print (student_id)
    print (student_name)
    system
    calculate _average("5001""45""78")
    def top_student( d)
    for(int i=0 to n)
    s=student_grade/sudent
    print(s)
